# %%
import pandas as pd

# %%
df = pd.read_csv("Air_Traffic_Landings_Statistics.csv")
df.head()
# Out:
#    Activity Period Operating Airline Operating Airline IATA Code  \
# 0           200507           ABX Air                          GB
# 1           200507           ABX Air                          GB
# 2           200507      ATA Airlines                          TZ
# 3           200507      ATA Airlines                          TZ
# 4           200507        Air Canada                          AC
#
#   Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# 0           ABX Air                          GB       Domestic         US
# 1           ABX Air                          GB       Domestic         US
# 2      ATA Airlines                          TZ       Domestic         US
# 3      ATA Airlines                          TZ       Domestic         US
# 4        Air Canada                          AC  International     Canada
#
#   Landing Aircraft Type Aircraft Body Type Aircraft Manufacturer  \
# ...

# %%
df.sort_values(["Aircraft Manufacturer", "Operating Airline"],inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\leona\OneDrive\Área de Trabalho\bdzin\dados.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/leona/OneDrive/%C3%81rea%20de%20Trabalho/bdzin/dados.ipynb#ch0000002?line=0'>1</a> df.sort_values(["Aircraft Manufacturer", "Operating Airline"],inplace=True).head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
import pandas as pd

df = pd.read_csv("Air_Traffic_Landings_Statistics.csv")

# %%
df.head(10)
# Out:
#    Activity Period Operating Airline Operating Airline IATA Code  \
# 0           200507           ABX Air                          GB
# 1           200507           ABX Air                          GB
# 2           200507      ATA Airlines                          TZ
# 3           200507      ATA Airlines                          TZ
# 4           200507        Air Canada                          AC
# 5           200507        Air Canada                          AC
# 6           200507        Air Canada                          AC
# 7           200507        Air Canada                          AC
# 8           200507         Air China                          CA
# 9           200507        Air France                          AF
#
#   Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# 0           ABX Air                          GB       Domestic         US
# 1           ABX Air                          GB       Domestic         US
# ...

# %%
df[df["Published Airline"] == "ATA Airlines"].head()
# Out:
#      Activity Period Operating Airline Operating Airline IATA Code  \
# 2             200507      ATA Airlines                          TZ
# 3             200507      ATA Airlines                          TZ
# 139           200508      ATA Airlines                          TZ
# 140           200508      ATA Airlines                          TZ
# 141           200508      ATA Airlines                          TZ
#
#     Published Airline Published Airline IATA Code GEO Summary GEO Region  \
# 2        ATA Airlines                          TZ    Domestic         US
# 3        ATA Airlines                          TZ    Domestic         US
# 139      ATA Airlines                          TZ    Domestic         US
# 140      ATA Airlines                          TZ    Domestic         US
# 141      ATA Airlines                          TZ    Domestic         US
#
#     Landing Aircraft Type Aircraft Body Type Aircraft Manufacturer  \
# ...

# %%
df[(df["Published Airline"] == "ATA Airlines") & (df["GEO Summary"] == "International")].head()
# Out:
#       Activity Period Operating Airline Operating Airline IATA Code  \
# 540            200511      ATA Airlines                          TZ
# 3375           200709      ATA Airlines                          TZ
#
#      Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# 540       ATA Airlines                          TZ  International     Canada
# 3375      ATA Airlines                          TZ  International     Canada
#
#      Landing Aircraft Type Aircraft Body Type Aircraft Manufacturer  \
# 540              Passenger        Narrow Body                Boeing
# 3375             Passenger        Narrow Body                Boeing
#
#      Aircraft Model Aircraft Version  Landing Count  Total Landed Weight
# 540             757              300              2               448000
# 3375            757              300              2               448000

# %%
df[(df["Aircraft Body Type"] == "Narrow Body") & ((df["GEO Region"] == "US") | (df["GEO Region"] == "Canada"))].head()
# Out:
#    Activity Period Operating Airline Operating Airline IATA Code  \
# 0           200507           ABX Air                          GB
# 1           200507           ABX Air                          GB
# 2           200507      ATA Airlines                          TZ
# 3           200507      ATA Airlines                          TZ
# 5           200507        Air Canada                          AC
#
#   Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# 0           ABX Air                          GB       Domestic         US
# 1           ABX Air                          GB       Domestic         US
# 2      ATA Airlines                          TZ       Domestic         US
# 3      ATA Airlines                          TZ       Domestic         US
# 5        Air Canada                          AC  International     Canada
#
#   Landing Aircraft Type Aircraft Body Type Aircraft Manufacturer  \
# ...
